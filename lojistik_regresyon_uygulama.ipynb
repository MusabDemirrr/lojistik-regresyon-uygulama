# %% [markdown]
# <a href="https://colab.research.google.com/github/MusabDemirrr/lojistik-regresyon-uygulama/blob/main/lojistik_regresyon_uygulama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lojisitk Regrresyon / Logistic Regression**

# %% [markdown]
# I have wrote this code by watching @Siddhardhan's Machine Learning Course With Python on youtube

# %%
# Gerekli kütüphaneleri yüklüyoruz
# İmporting the libraries
import numpy as np

# %%
class LojistikRegresyon():

  def __init__(self,ogrenme_hizi,egitim_sayisi):

    self.egitim_sayisi = egitim_sayisi
    self.ogrenme_hizi = ogrenme_hizi


  def egitim(self,X,Y):

    self.X = X
    self.Y = Y
    self.veri_sayisi,self.ozellik_sayisi = X.shape

    self.agirliklar = np.zeros(self.ozellik_sayisi)
    self.biyas = 0

    for _ in range(self.egitim_sayisi):
      self.agirlik_guncelleme()



  def agirlik_guncelleme(self):
    # modelin tahmini sonuç 0-1 arası bir olasılık değeri
    tahminler = 1 / (np.exp(-(self.X.dot(self.agirliklar) + self.biyas)) + 1)

    #  maliyet fonksiyonunun ağırlıklara göre türevi
    da = (1/self.veri_sayisi) * self.X.T.dot(tahminler - self.Y)
    #  maliyet fonksiyonunun biyasa göre türevi
    db = (1/self.veri_sayisi) * np.sum(tahminler - self.Y)

    # gradyan inişi kullanarak ağırlıkları ve biyası gücelleme
    self.agirliklar = self.agirliklar - self.ogrenme_hizi * da
    self.biyas = self.biyas - self.ogrenme_hizi * db



  def tahmin(self,X):

    olasılık_tahminleri = 1 / (np.exp(-(X.dot(self.agirliklar) + self.biyas)) + 1)

    tahminler = np.where(olasılık_tahminleri >= 0.5 ,1 ,0)

    return tahminler

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
diyabet_verileri = pd.read_csv("/content/diabetes (3).csv")

# %%
diyabet_verileri.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diyabet_verileri.shape
# Out:
# (768, 9)

# %%
diyabet_verileri.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diyabet_verileri["Outcome"].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diyabet_verileri.groupby("Outcome").mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
girdiler = diyabet_verileri.drop("Outcome",axis=1)
sonuclar = diyabet_verileri["Outcome"]

# %%
scaler = StandardScaler()
scaler.fit(girdiler)
standartize_girdiler = scaler.transform(girdiler)

# %%
print(standartize_girdiler)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
x_eğitim, x_test, y_eğitim, y_test = train_test_split(standartize_girdiler,sonuclar,test_size=0.3,random_state=37)

# %%
print(x_eğitim.shape,"\n\n")
print(x_test)
# Out:
# (537, 8)
#
#
# [[-0.84488505  0.37886661  1.70057325 ...  0.10247738 -0.71841466
#    1.00055664]
#  [-0.54791859 -0.99820778  1.08020025 ...  0.19132085 -0.54324778
#    0.74529338]
#  [ 0.3429808  -0.68523633  0.25303625 ... -0.37981576 -0.81203834
#   -0.10558415]
#  ...
#  [-1.14185152 -0.74783062 -0.26394125 ...  0.61015436  0.38694877
#   -0.70119842]
#  [-0.84488505 -1.02950492 -0.36733675 ... -0.26558844 -0.15063235
#   -0.87137393]
#  [ 1.23388019  2.10020961  0.45982725 ...  2.01895798 -1.01136617
#    0.83038113]]

# %%
print(y_eğitim.shape,"\n\n")
print(y_test)
# Out:
# (537,)
#
#
# 369    1
# 491    0
# 65     0
# 269    1
# 432    0
#       ..
# 172    0
# 176    0
# 467    0
# 553    0
# 154    1
# Name: Outcome, Length: 231, dtype: int64

# %%
model = LojistikRegresyon(ogrenme_hizi=0.2,egitim_sayisi=500)

# %%
model.egitim(x_eğitim,y_eğitim.T)

# %%
y_egitim_tahmin = model.tahmin(x_eğitim)
eğitim_verisi_tahmin_doğruluğu = accuracy_score(y_eğitim,y_egitim_tahmin)
print(eğitim_verisi_tahmin_doğruluğu)
# Out:
# 0.7728119180633147

# %%
y_test_tahmin = model.tahmin(x_test)
test_verisi_tahmin_doğruluğu = accuracy_score(y_test,y_test_tahmin)
print(test_verisi_tahmin_doğruluğu)
# Out:
# 0.7878787878787878
